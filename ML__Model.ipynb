# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing and Reading the Combined Data

# %%
df = pd.read_csv('C:/Users/Green Events/Desktop/Singapore_flat_resale/combined.csv')
df
# Out:
#         latitude   longitude blk_no        road_name  postal_code  \
# 0       1.303671  103.864479      1       BEACH ROAD       190001
# 1       1.303671  103.864479      1       BEACH ROAD       190001
# 2       1.303671  103.864479      1       BEACH ROAD       190001
# 3       1.303671  103.864479      1       BEACH ROAD       190001
# 4       1.303671  103.864479      1       BEACH ROAD       190001
# ...          ...         ...    ...              ...          ...
# 219366  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219367  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219368  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219369  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219370  1.286814  103.828928     9B  BOON TIONG ROAD       163009
#
#                  address     cbd_dist  min_dist_mrt    month             town  \
# 0             1 BEACH RD  2715.822202    457.092359  2015-01  KALLANG/WHAMPOA
# 1             1 BEACH RD  2715.822202    457.092359  2016-03  KALLANG/WHAMPOA
# 2             1 BEACH RD  2715.822202    457.092359  2017-04  KALLANG/WHAMPOA
# 3             1 BEACH RD  2715.822202    457.092359  2017-05  KALLANG/WHAMPOA
# 4             1 BEACH RD  2715.822202    457.092359  2017-06  KALLANG/WHAMPOA
# ...                  ...          ...           ...      ...              ...
# 219366  9B BOON TIONG RD  2525.251132    182.864524  2023-05      BUKIT MERAH
# 219367  9B BOON TIONG RD  2525.251132    182.864524  2023-08      BUKIT MERAH
# 219368  9B BOON TIONG RD  2525.251132    182.864524  2023-12      BUKIT MERAH
# 219369  9B BOON TIONG RD  2525.251132    182.864524  2024-03      BUKIT MERAH
# 219370  9B BOON TIONG RD  2525.251132    182.864524  2024-06      BUKIT MERAH
#
#        flat_type block    street_name storey_range  floor_area_sqm flat_model  \
# 0         3 ROOM     1       BEACH RD     04 TO 06            74.0   Improved
# 1         3 ROOM     1       BEACH RD     07 TO 09            68.0   Improved
# 2         3 ROOM     1       BEACH RD     07 TO 09            68.0   Improved
# 3         3 ROOM     1       BEACH RD     07 TO 09            68.0   Improved
# 4         3 ROOM     1       BEACH RD     07 TO 09            68.0   Improved
# ...          ...   ...            ...          ...             ...        ...
# 219366    5 ROOM    9B  BOON TIONG RD     07 TO 09           112.0   Improved
# 219367    5 ROOM    9B  BOON TIONG RD     22 TO 24           112.0   Improved
# 219368    5 ROOM    9B  BOON TIONG RD     19 TO 21           112.0   Improved
# 219369    4 ROOM    9B  BOON TIONG RD     25 TO 27            92.0    Model A
# 219370    5 ROOM    9B  BOON TIONG RD     34 TO 36           112.0   Improved
#
#         lease_commence_date  resale_price     remaining_lease  \
# 0                      1979      388000.0                  63
# 1                      1979      350000.0                  62
# 2                      1979      340000.0  61 years 05 months
# 3                      1979      322000.0  61 years 05 months
# 4                      1979      370000.0  61 years 03 months
# ...                     ...           ...                 ...
# 219366                 2016     1278000.0  91 years 09 months
# 219367                 2016     1325000.0  91 years 05 months
# 219368                 2016     1400000.0  91 years 02 months
# 219369                 2016     1188000.0  90 years 11 months
# 219370                 2016     1588000.0  90 years 08 months
#
#         lease_remain_years
# 0                       55
# 1                       55
# 2                       55
# 3                       55
# 4                       55
# ...                    ...
# 219366                  92
# 219367                  92
# 219368                  92
# 219369                  92
# 219370                  92
#
# [219371 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# ## Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no        road_name  postal_code  \
# 0       1.303671  103.864479      1       BEACH ROAD       190001
# 1       1.303671  103.864479      1       BEACH ROAD       190001
# 2       1.303671  103.864479      1       BEACH ROAD       190001
# 3       1.303671  103.864479      1       BEACH ROAD       190001
# 4       1.303671  103.864479      1       BEACH ROAD       190001
# ...          ...         ...    ...              ...          ...
# 219366  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219367  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219368  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219369  1.286814  103.828928     9B  BOON TIONG ROAD       163009
# 219370  1.286814  103.828928     9B  BOON TIONG ROAD       163009
#
#                  address     cbd_dist  min_dist_mrt    month             town  \
# 0             1 BEACH RD  2715.822202    457.092359  2015-01  KALLANG/WHAMPOA
# 1             1 BEACH RD  2715.822202    457.092359  2016-03  KALLANG/WHAMPOA
# 2             1 BEACH RD  2715.822202    457.092359  2017-04  KALLANG/WHAMPOA
# 3             1 BEACH RD  2715.822202    457.092359  2017-05  KALLANG/WHAMPOA
# 4             1 BEACH RD  2715.822202    457.092359  2017-06  KALLANG/WHAMPOA
# ...                  ...          ...           ...      ...              ...
# 219366  9B BOON TIONG RD  2525.251132    182.864524  2023-05      BUKIT MERAH
# 219367  9B BOON TIONG RD  2525.251132    182.864524  2023-08      BUKIT MERAH
# 219368  9B BOON TIONG RD  2525.251132    182.864524  2023-12      BUKIT MERAH
# 219369  9B BOON TIONG RD  2525.251132    182.864524  2024-03      BUKIT MERAH
# 219370  9B BOON TIONG RD  2525.251132    182.864524  2024-06      BUKIT MERAH
#
#         ... block    street_name storey_range floor_area_sqm  flat_model  \
# 0       ...     1       BEACH RD     04 TO 06           74.0    Improved
# 1       ...     1       BEACH RD     07 TO 09           68.0    Improved
# 2       ...     1       BEACH RD     07 TO 09           68.0    Improved
# 3       ...     1       BEACH RD     07 TO 09           68.0    Improved
# 4       ...     1       BEACH RD     07 TO 09           68.0    Improved
# ...     ...   ...            ...          ...            ...         ...
# 219366  ...    9B  BOON TIONG RD     07 TO 09          112.0    Improved
# 219367  ...    9B  BOON TIONG RD     22 TO 24          112.0    Improved
# 219368  ...    9B  BOON TIONG RD     19 TO 21          112.0    Improved
# 219369  ...    9B  BOON TIONG RD     25 TO 27           92.0     Model A
# 219370  ...    9B  BOON TIONG RD     34 TO 36          112.0    Improved
#
#        lease_commence_date  resale_price     remaining_lease  \
# 0                     1979      388000.0                  63
# 1                     1979      350000.0                  62
# 2                     1979      340000.0  61 years 05 months
# 3                     1979      322000.0  61 years 05 months
# 4                     1979      370000.0  61 years 03 months
# ...                    ...           ...                 ...
# 219366                2016     1278000.0  91 years 09 months
# 219367                2016     1325000.0  91 years 05 months
# 219368                2016     1400000.0  91 years 02 months
# 219369                2016     1188000.0  90 years 11 months
# 219370                2016     1588000.0  90 years 08 months
#
#        lease_remain_years  storey_median
# 0                      55            5.0
# 1                      55            8.0
# 2                      55            8.0
# 3                      55            8.0
# 4                      55            8.0
# ...                   ...            ...
# 219366                 92            8.0
# 219367                 92           23.0
# 219368                 92           20.0
# 219369                 92           26.0
# 219370                 92           35.0
#
# [219371 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#            cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       2715.822202    457.092359            74.0                  55
# 1       2715.822202    457.092359            68.0                  55
# 2       2715.822202    457.092359            68.0                  55
# 3       2715.822202    457.092359            68.0                  55
# 4       2715.822202    457.092359            68.0                  55
# ...             ...           ...             ...                 ...
# 219366  2525.251132    182.864524           112.0                  92
# 219367  2525.251132    182.864524           112.0                  92
# 219368  2525.251132    182.864524           112.0                  92
# 219369  2525.251132    182.864524            92.0                  92
# 219370  2525.251132    182.864524           112.0                  92
#
#         storey_median  resale_price
# 0                 5.0      388000.0
# 1                 8.0      350000.0
# 2                 8.0      340000.0
# 3                 8.0      322000.0
# 4                 8.0      370000.0
# ...               ...           ...
# 219366            8.0     1278000.0
# 219367           23.0     1325000.0
# 219368           20.0     1400000.0
# 219369           26.0     1188000.0
# 219370           35.0     1588000.0
#
# [219371 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#            cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       2715.822202    457.092359            74.0                  55
# 1       2715.822202    457.092359            68.0                  55
# 2       2715.822202    457.092359            68.0                  55
# 3       2715.822202    457.092359            68.0                  55
# 4       2715.822202    457.092359            68.0                  55
# ...             ...           ...             ...                 ...
# 219366  2525.251132    182.864524           112.0                  92
# 219367  2525.251132    182.864524           112.0                  92
# 219368  2525.251132    182.864524           112.0                  92
# 219369  2525.251132    182.864524            92.0                  92
# 219370  2525.251132    182.864524           112.0                  92
#
#         storey_median  resale_price
# 0                 5.0      388000.0
# 1                 8.0      350000.0
# 2                 8.0      340000.0
# 3                 8.0      322000.0
# 4                 8.0      370000.0
# ...               ...           ...
# 219366            8.0     1278000.0
# 219367           23.0     1325000.0
# 219368           20.0     1400000.0
# 219369           26.0     1188000.0
# 219370           35.0     1588000.0
#
# [212691 rows x 6 columns]

# %% [markdown]
# ## Checking and Handling for Skewness in the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# ## Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# ## Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -2.213492 -0.754575 -0.947463 -1.188638 -0.442478
# 1      -2.213492 -0.754575 -1.276859 -1.188638  0.211888
# 2      -2.213492 -0.754575 -1.276859 -1.188638  0.211888
# 3      -2.213492 -0.754575 -1.276859 -1.188638  0.211888
# 4      -2.213492 -0.754575 -1.276859 -1.188638  0.211888
# ...          ...       ...       ...       ...       ...
# 212686 -2.256816 -1.380276  0.666976  1.525876  0.211888
# 212687 -2.256816 -1.380276  0.666976  1.525876  1.682186
# 212688 -2.256816 -1.380276  0.666976  1.525876  1.487601
# 212689 -2.256816 -1.380276 -0.099315  1.525876  1.852880
# 212690 -2.256816 -1.380276  0.666976  1.525876  2.266731
#
# [212691 rows x 5 columns]

# %% [markdown]
# ## Splitting the data for training and testing purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 4}
#
# Mean squared error: 0.017285381588401198
# Mean Absolute Error 0.10521130820890916
# Root Mean squared error: 0.13147388177277342
#
# R-squared: 0.8431527461875088

# %% [markdown]
# ## Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 228780.31448160246

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
from IPython.display import FileLink

FileLink('model.pkl', result_html_prefix="Click to download: ")
# Out:
# c:\Users\Green Events\Desktop\Singapore_flat_resale\model.pkl

# %%
FileLink('scaler.pkl', result_html_prefix="Click to download: ")
# Out:
# c:\Users\Green Events\Desktop\Singapore_flat_resale\scaler.pkl
